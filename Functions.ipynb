# %%
LAST_NAME =  "Mandapat"
STUDENT_ID = "TUPM-25-0704"

SEED_DIGIT = int(STUDENT_ID [-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:", SEED_DIGIT)
print("Digital Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: Mandapat
# Seed Digit: 4
# Digital Sum: 18
# Surname Length: 8

# %%
def greet():
    print("=" * 40)
    print(f"System Initialized for: {LAST_NAME}")
    print("=" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code

greet()
print("Identity Code:", identity_code())
# Out:
# ========================================
# System Initialized for: Mandapat
# ========================================
# Identity Code: 32

# %%
global_value = SEED_DIGIT

def scope_test():
    global_value = SEED_DIGIT
    print("Inside function:", global_value)

scope_test()
print("Outside function:", global_value)
# Out:
# Inside function: 4
# Outside function: 4

# %%
def user_summary(title, *scores, **info):
    print(f"=== {title} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average:", round (average,2))

    for k,v in info.items():
        print(f"{k}: {v}")

    return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id=STUDENT_ID,
    surname=LAST_NAME
)
# Out:
# === Mandapat Academic Report ===
# Scores: (40, 18, 40)
# Total: 98
# Average: 32.67
# id: TUPM-25-0704
# surname: Mandapat

# %%
def compute_area(radius):
    return 3.1416 * radius**2

area = compute_area(SEED_DIGIT + 2)
print("Compute Area:", round(area,2))
# Out:
# Compute Area: 113.1

# %%
def safe_calculator(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        result = "UNDEFINED"
    return result

print("Calculation Result:", safe_calculator(ID_SUM, SEED_DIGIT))
# Out:
# Calculation Result: 4.5

# %%
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n-1)

print("Factorial Result", factorial(SEED_DIGIT))
# Out:
# Factorial Result 24

# %%
def reverse(text):
    if len(text) <= 1:
        return text
    return text [-1] + reverse(text[;-1])

print("Reversed Surname:", reverse(LAST_NAME.upper()))
